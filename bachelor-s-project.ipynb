# %% [markdown]
# # RAFT

# %%
# ! wget http://files.is.tue.mpg.de/sintel/MPI-Sintel-complete.zip

# %%
# ! unzip MPI-Sintel-complete.zip -d sintel

# %%
! wget https://s3.eu-central-1.amazonaws.com/avg-kitti/data_scene_flow.zip
# Out:
# --2024-04-16 03:56:44--  https://s3.eu-central-1.amazonaws.com/avg-kitti/data_scene_flow.zip
# Resolving s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)... 52.219.169.197, 52.219.170.57, 52.219.170.109, ...
# Connecting to s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)|52.219.169.197|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1681488619 (1.6G) [application/zip]
# Saving to: 'data_scene_flow.zip'
#
# data_scene_flow.zip 100%[===================>]   1.57G  19.7MB/s    in 87s
#
# 2024-04-16 03:58:11 (18.5 MB/s) - 'data_scene_flow.zip' saved [1681488619/1681488619]

# %%
! unzip data_scene_flow.zip -d KITTI
# Out:
# Archive:  data_scene_flow.zip
#    creating: KITTI/training/
#    creating: KITTI/training/disp_noc_1/
#  extracting: KITTI/training/disp_noc_1/000033_10.png
#  extracting: KITTI/training/disp_noc_1/000076_10.png
#  extracting: KITTI/training/disp_noc_1/000194_10.png
#  extracting: KITTI/training/disp_noc_1/000137_10.png
#  extracting: KITTI/training/disp_noc_1/000110_10.png
#  extracting: KITTI/training/disp_noc_1/000188_10.png
#  extracting: KITTI/training/disp_noc_1/000015_10.png
#  extracting: KITTI/training/disp_noc_1/000155_10.png
#  extracting: KITTI/training/disp_noc_1/000128_10.png
#  extracting: KITTI/training/disp_noc_1/000162_10.png
#  extracting: KITTI/training/disp_noc_1/000144_10.png
#  extracting: KITTI/training/disp_noc_1/000052_10.png
#  extracting: KITTI/training/disp_noc_1/000121_10.png
#  extracting: KITTI/training/disp_noc_1/000193_10.png
#  extracting: KITTI/training/disp_noc_1/000171_10.png
#  extracting: KITTI/training/disp_noc_1/000101_10.png
# ...

# %%
# I have cloned once. So do not run this cell.
# ! git clone https://github.com/princeton-vl/RAFT.git
# !git clone https://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@github.com/aheldis/UMAD.git
# Out:
# Cloning into 'UMAD'...
# remote: Enumerating objects: 863, done.
# remote: Counting objects: 100% (242/242), done.
# remote: Compressing objects: 100% (136/136), done.
# remote: Total 863 (delta 124), reused 208 (delta 106), pack-reused 621
# Receiving objects: 100% (863/863), 146.07 MiB | 52.72 MiB/s, done.
# Resolving deltas: 100% (256/256), done.

# %%
# !ls
# %cd kaggle
# !ls input/lasttrain

# %%
# %cd UMAD
# Out:
# /kaggle/working/UMAD

# %%
ls
# Out:
# LICENSE         chairs_split.txt  download_models.sh  runs/
# RAFT.png        core/             evaluate.py         train.py
# README.md       demo-frames/      models.zip          train_mixed.sh
# alt_cuda_corr/  demo.py           output/             train_standard.sh

# %%
# I have downloaded the models once. So do not run this cell
# ! sh download_models.sh

# %%
# new demo.py
# ! rm demo.py
# ! wget https://www.dropbox.com/s/bwk2bv0so72a8ma/demo.py

# %%
# ! python demo.py --model=models/raft-things.pth --path=demo-frames

# %%
368/2, 768/2
# Out:
# (184.0, 384.0)

# %%
# ! sh train_standard.sh
# [steps, learning rate] px1, px2, px3, epe
# torch.Size([12, 64, 92, 192])
# torch.Size([6, 64, 92, 192])

# %%
# !sh download_models.sh
# Out:
# --2024-04-16 03:58:38--  https://www.dropbox.com/s/4j4z58wuv8o0mfz/models.zip
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.1.18, 2620:100:6016:18::a27d:112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.1.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/4j4z58wuv8o0mfz/models.zip [following]
# --2024-04-16 03:58:38--  https://www.dropbox.com/s/raw/4j4z58wuv8o0mfz/models.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc7f46d6d6dc375b86d6aa69bdac.dl.dropboxusercontent.com/cd/0/inline/CRE_tnBhFED4CPiNWTLyl-PWqMiwZYOIlAJcIEsT7AcXEx-hKhdidIVMijY7A0J89LObXRAZyztqZHLW8ejw_oH2SQIGTntkJmmP6Mw8S1c70Sadzx_5RblwZ76eMUo1EIeDO2x1rsjZLD4qmfJ92eFL/file# [following]
# ...

# %%
# !python evaluate.py --model=checkpoints/25000_last.pth --dataset=sintel --mixed_precision
# !python evaluate.py --model=models/raft-things.pth --dataset=sintel --mixed_precision --channel=-1 --iters=10
# !python evaluate.py --model=models/raft-things.pth --dataset=kitti --mixed_precision --channel=-1 --iters=10 --attack_type=PGD --output_path="output"
# Out:
#   File "/kaggle/working/UMAD/evaluate.py", line 222
#     viz(args, image1, flow_pr, "flow")
#                                       ^
# IndentationError: unindent does not match any outer indentation level

# %%
ls
# Out:
# LICENSE           core/               models/       train.py
# RAFT.png          demo-frames/        models.zip    train_mixed.sh
# README.md         demo.py             models.zip.1  train_standard.sh
# alt_cuda_corr/    download_models.sh  output/
# chairs_split.txt  evaluate.py         runs/

# %%
cd ..
# Out:
# /kaggle/working

# %%
rm -r UMAD

# %%
# ! git config --global user.email "ehsanihani30@yahoo.com"
# ! git config --global user.name "aheldis"

# %%
# ! git add .

# %%
# ! git commit -m "edit for run"

# %%
# ! git push -u -f origin master

# %%
# ! git remote -v
